# %%
import pandas as pd
import json
import numpy as np
import seaborn as sn
from matplotlib import pyplot as plt
from io import StringIO
# %matplotlib inline

# %%
#####Dataset taken from - https://www.kaggle.com/datasets/ahsanaseer/top-rated-tmdb-movies-10k ########
df_10k_movies = pd.read_csv('10kMovies.csv')

# %%
###EDA AND FEATURE ANALYSIS ###

# %%
df_10k_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 10000 non-null  int64
#  1   title              10000 non-null  object
#  2   genre              9997 non-null   object
#  3   original_language  10000 non-null  object
#  4   overview           9987 non-null   object
#  5   popularity         10000 non-null  float64
#  6   release_date       10000 non-null  object
#  7   vote_average       10000 non-null  float64
#  8   vote_count         10000 non-null  int64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 703.3+ KB

# %%
df_10k_movies.describe()
# Out:
#                   id    popularity  vote_average    vote_count
# count   10000.000000  10000.000000  10000.000000  10000.000000
# mean   161243.505000     34.697267      6.621150   1547.309400
# std    211422.046043    211.684175      0.766231   2648.295789
# min         5.000000      0.600000      4.600000    200.000000
# 25%     10127.750000      9.154750      6.100000    315.000000
# 50%     30002.500000     13.637500      6.600000    583.500000
# 75%    310133.500000     25.651250      7.200000   1460.000000
# max    934761.000000  10436.917000      8.700000  31917.000000

# %%
df_10k_movies.isna().sum()
# Out:
# id                    0
# title                 0
# genre                 3
# original_language     0
# overview             13
# popularity            0
# release_date          0
# vote_average          0
# vote_count            0
# dtype: int64

# %%
df_10k_movies.nunique()
# Out:
# id                   10000
# title                 9661
# genre                 2123
# original_language       43
# overview              9985
# popularity            8511
# release_date          6113
# vote_average            42
# vote_count            3191
# dtype: int64

# %%
df_10k_movies.dtypes
# Out:
# id                     int64
# title                 object
# genre                 object
# original_language     object
# overview              object
# popularity           float64
# release_date          object
# vote_average         float64
# vote_count             int64
# dtype: object

# %%
df_10k_movies = df_10k_movies.fillna('NA')

# %%
df_10k_movies.isna().sum()
# Out:
# id                   0
# title                0
# genre                0
# original_language    0
# overview             0
# popularity           0
# release_date         0
# vote_average         0
# vote_count           0
# dtype: int64

# %%
#### Data Cleaning #####

# %%
df_10k_movies_duped_titles = df_10k_movies[df_10k_movies.duplicated(subset=['title'],keep=False)]

# %%
df_10k_movies_duped_titles
# Out:
#           id                  title                          genre  \
# 10       389           12 Angry Men                          Drama
# 28       539                 Psycho          Horror,Drama,Thriller
# 50    244786               Whiplash                    Drama,Music
# 88    637920  Miracle in Cell No. 7                   Drama,Comedy
# 90       670                 Oldboy  Drama,Thriller,Mystery,Action
# ...      ...                    ...                            ...
# 9933  416160              The Vault                Horror,Thriller
# 9939   21943             I Want You                 Romance,Comedy
# 9991  551808        Black Christmas        Horror,Mystery,Thriller
# 9992  853588                   Prey                       Thriller
# 9999  455957                 Domino          Thriller,Action,Crime
#
#      original_language                                           overview  \
# 10                  en  The defense and the prosecution have rested an...
# 28                  en  When larcenous real estate clerk Marion Crane ...
# 50                  en  Under the direction of a ruthless instructor, ...
# 88                  tr  Separated from his daughter, a father with an ...
# 90                  ko  With no clue how he came to be imprisoned, dru...
# ...                ...                                                ...
# 9933                en  Two estranged sisters are forced to rob a bank...
# 9939                it  A macho type man becomes entangled with an ind...
# 9991                en  During Christmas break, the women at Hawthorne...
# 9992                de  A hiking trip into the wild turns into a despe...
# 9999                en  Seeking justice for his partner’s murder by an...
#
#       popularity release_date  vote_average  vote_count
# 10        31.946   1957-04-10           8.5        6533
# 28        41.575   1960-06-22           8.4        8288
# 50        57.858   2014-10-10           8.4       12371
# 88        49.021   2019-10-10           8.3        3968
# 90        29.817   2003-11-21           8.3        6806
# ...          ...          ...           ...         ...
# 9933       8.219   2017-09-01           4.8         328
# 9939       5.706   2007-03-09           4.8         310
# 9991       9.811   2019-12-11           4.7         412
# 9992      64.052   2021-09-10           4.7         254
# 9999      16.482   2019-05-31           4.6         221
#
# [653 rows x 9 columns]

# %%
len(df_10k_movies['title']) - df_10k_movies['title'].nunique()
# Out:
# 339

# %%
non_unique_movies = df_10k_movies[df_10k_movies.duplicated(subset=['title'])]
len(non_unique_movies)
# Out:
# 339

# %%
df_no_duplicates = df_10k_movies.drop_duplicates(subset=['title'])

# %%
len(df_no_duplicates)
# Out:
# 9661

# %%
df_no_duplicates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9661 entries, 0 to 9998
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 9661 non-null   int64
#  1   title              9661 non-null   object
#  2   genre              9661 non-null   object
#  3   original_language  9661 non-null   object
#  4   overview           9661 non-null   object
#  5   popularity         9661 non-null   float64
#  6   release_date       9661 non-null   object
#  7   vote_average       9661 non-null   float64
#  8   vote_count         9661 non-null   int64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 754.8+ KB

# %%
target_col = 'genre'
condition = df_no_duplicates[target_col].str.len() <3
short_values = df_no_duplicates[condition]
short_values
# Out:
#          id                    title genre original_language  \
# 3361  50472     Anplagghed al cinema    NA                it
# 7821  43211        7 Kilos in 7 Days    NA                it
# 8518  57114  Amore, bugie e calcetto    NA                en
#
#                                                overview  popularity  \
# 3361  A queue at the ATM machine, a displaced family...       4.420
# 7821  Two not very clever young doctors open a fitne...       5.885
# 8518                                                 NA       4.709
#
#      release_date  vote_average  vote_count
# 3361   2006-11-26           7.0         313
# 7821   1986-02-02           6.0         212
# 8518   2008-04-04           5.8         200

# %%
short_genres = df_no_duplicates.loc[condition, target_col]
short_genres
# Out:
# 3361    NA
# 7821    NA
# 8518    NA
# Name: genre, dtype: object

# %%
row_indices = df_no_duplicates.loc[condition].index.to_list()
row_indices
# Out:
# [3361, 7821, 8518]

# %%
df_no_duplicates_with_cleaned_genres = df_no_duplicates.drop(row_indices)
len(df_no_duplicates_with_cleaned_genres)
# Out:
# 9658

# %%
df_no_duplicates_with_cleaned_genres.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9658 entries, 0 to 9998
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 9658 non-null   int64
#  1   title              9658 non-null   object
#  2   genre              9658 non-null   object
#  3   original_language  9658 non-null   object
#  4   overview           9658 non-null   object
#  5   popularity         9658 non-null   float64
#  6   release_date       9658 non-null   object
#  7   vote_average       9658 non-null   float64
#  8   vote_count         9658 non-null   int64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 754.5+ KB

# %%
df_no_duplicates_with_cleaned_genres.describe()
# Out:
#                  id    popularity  vote_average    vote_count
# count    9658.00000   9658.000000   9658.000000   9658.000000
# mean   161230.86695     34.967737      6.636188   1550.660592
# std    211567.65833    215.302056      0.766584   2666.105446
# min         5.00000      0.600000      4.600000    200.000000
# 25%     10119.00000      9.114250      6.100000    315.000000
# 50%     29456.50000     13.581500      6.600000    582.500000
# 75%    309866.75000     25.426000      7.200000   1453.750000
# max    934761.00000  10436.917000      8.700000  31917.000000

# %%
df_no_duplicates_with_cleaned_genres.reset_index()
# Out:
#       index      id                                          title  \
# 0         0     278                       The Shawshank Redemption
# 1         1   19404                    Dilwale Dulhania Le Jayenge
# 2         2     238                                  The Godfather
# 3         3     424                               Schindler's List
# 4         4     240                         The Godfather: Part II
# ...     ...     ...                                            ...
# 9653   9994  168098                                           Cell
# 9654   9995   10196                             The Last Airbender
# 9655   9996  331446                       Sharknado 3: Oh Hell No!
# 9656   9997   13995                                Captain America
# 9657   9998    2312  In the Name of the King: A Dungeon Siege Tale
#
#                                                  genre original_language  \
# 0                                          Drama,Crime                en
# 1                                 Comedy,Drama,Romance                hi
# 2                                          Drama,Crime                en
# 3                                    Drama,History,War                en
# 4                                          Drama,Crime                en
# ...                                                ...               ...
# 9653                   Horror,Science Fiction,Thriller                en
# 9654                          Action,Adventure,Fantasy                en
# 9655  Action,TV Movie,Science Fiction,Comedy,Adventure                en
# 9656                        Action,Science Fiction,War                en
# 9657                    Adventure,Fantasy,Action,Drama                en
#
#                                                overview  popularity  \
# 0     Framed in the 1940s for the double murder of h...      94.075
# 1     Raj is a rich, carefree, happy-go-lucky second...      25.408
# 2     Spanning the years 1945 to 1955, a chronicle o...      90.585
# 3     The true story of how businessman Oskar Schind...      44.761
# 4     In the continuing saga of the Corleone crime f...      57.749
# ...                                                 ...         ...
# 9653  When a strange signal pulsates through all cel...      19.521
# 9654  The story follows the adventures of Aang, a yo...      98.322
# 9655  The sharks take bite out of the East Coast whe...      12.490
# 9656  During World War II, a brave, patriotic Americ...      18.333
# 9657  A man named Farmer sets out to rescue his kidn...      15.159
#
#      release_date  vote_average  vote_count
# 0      1994-09-23           8.7       21862
# 1      1995-10-19           8.7        3731
# 2      1972-03-14           8.7       16280
# 3      1993-12-15           8.6       12959
# 4      1974-12-20           8.6        9811
# ...           ...           ...         ...
# 9653   2016-07-06           4.7         910
# 9654   2010-06-30           4.7        3347
# 9655   2015-07-22           4.7         417
# 9656   1990-12-14           4.6         332
# 9657   2007-11-29           4.7         668
#
# [9658 rows x 10 columns]

# %%
df_no_duplicates_with_cleaned_genres['release_date'] = pd.to_datetime(df_no_duplicates_with_cleaned_genres['release_date'])

# %%
df_no_duplicates_with_cleaned_genres['genre'].head()
# Out:
# 0             Drama,Crime
# 1    Comedy,Drama,Romance
# 2             Drama,Crime
# 3       Drama,History,War
# 4             Drama,Crime
# Name: genre, dtype: object

# %%
genres = df_no_duplicates_with_cleaned_genres.loc[:, ['id', 'genre']]
genres.head()
# Out:
#       id                 genre
# 0    278           Drama,Crime
# 1  19404  Comedy,Drama,Romance
# 2    238           Drama,Crime
# 3    424     Drama,History,War
# 4    240           Drama,Crime

# %%
genres_list = genres['genre'].str.split(',').tolist()
genres_list[1], len(genres_list)
# Out:
# (['Comedy', 'Drama', 'Romance'], 9658)

# %%
for i in range(len(genres_list)):
    if not(genres_list[i], list):
        genres_list[i] = [genres_list[i]]

# %%
stacked_genre = pd.DataFrame(genres_list, index=genres['id']).stack()
stacked_genre.head()
# Out:
# id
# 278    0      Drama
#        1      Crime
# 19404  0     Comedy
#        1      Drama
#        2    Romance
# dtype: object

# %%
stacked_genre = stacked_genre.reset_index()

# %%
stacked_genre = stacked_genre.loc[:, ['id',0]]
stacked_genre.columns = ['id','genre']
stacked_genre.head()
# Out:
#       id    genre
# 0    278    Drama
# 1    278    Crime
# 2  19404   Comedy
# 3  19404    Drama
# 4  19404  Romance

# %%
merged_df_movies  = pd.merge(df_no_duplicates_with_cleaned_genres, stacked_genre, on='id', how='left')
merged_df_movies.drop(['genre_x', 'overview'], axis=1, inplace=True)
merged_df_movies = merged_df_movies.rename(columns={'genre_y': 'genre'})
merged_df_movies.head()
# Out:
#       id                        title original_language  popularity  \
# 0    278     The Shawshank Redemption                en      94.075
# 1    278     The Shawshank Redemption                en      94.075
# 2  19404  Dilwale Dulhania Le Jayenge                hi      25.408
# 3  19404  Dilwale Dulhania Le Jayenge                hi      25.408
# 4  19404  Dilwale Dulhania Le Jayenge                hi      25.408
#
#   release_date  vote_average  vote_count    genre
# 0   1994-09-23           8.7       21862    Drama
# 1   1994-09-23           8.7       21862    Crime
# 2   1995-10-19           8.7        3731   Comedy
# 3   1995-10-19           8.7        3731    Drama
# 4   1995-10-19           8.7        3731  Romance

# %%
df_no_duplicates_with_cleaned_genres['year'] = df_no_duplicates_with_cleaned_genres['release_date'].dt.year
df_no_duplicates_with_cleaned_genres.head()
# Out:
#       id                        title                 genre original_language  \
# 0    278     The Shawshank Redemption           Drama,Crime                en
# 1  19404  Dilwale Dulhania Le Jayenge  Comedy,Drama,Romance                hi
# 2    238                The Godfather           Drama,Crime                en
# 3    424             Schindler's List     Drama,History,War                en
# 4    240       The Godfather: Part II           Drama,Crime                en
#
#                                             overview  popularity release_date  \
# 0  Framed in the 1940s for the double murder of h...      94.075   1994-09-23
# 1  Raj is a rich, carefree, happy-go-lucky second...      25.408   1995-10-19
# 2  Spanning the years 1945 to 1955, a chronicle o...      90.585   1972-03-14
# 3  The true story of how businessman Oskar Schind...      44.761   1993-12-15
# 4  In the continuing saga of the Corleone crime f...      57.749   1974-12-20
#
#    vote_average  vote_count  year
# 0           8.7       21862  1994
# 1           8.7        3731  1995
# 2           8.7       16280  1972
# 3           8.6       12959  1993
# 4           8.6        9811  1974

# %%
merged_df_movies['year'] = merged_df_movies['release_date'].dt.year
merged_df_movies.head()
# Out:
#       id                        title original_language  popularity  \
# 0    278     The Shawshank Redemption                en      94.075
# 1    278     The Shawshank Redemption                en      94.075
# 2  19404  Dilwale Dulhania Le Jayenge                hi      25.408
# 3  19404  Dilwale Dulhania Le Jayenge                hi      25.408
# 4  19404  Dilwale Dulhania Le Jayenge                hi      25.408
#
#   release_date  vote_average  vote_count    genre  year
# 0   1994-09-23           8.7       21862    Drama  1994
# 1   1994-09-23           8.7       21862    Crime  1994
# 2   1995-10-19           8.7        3731   Comedy  1995
# 3   1995-10-19           8.7        3731    Drama  1995
# 4   1995-10-19           8.7        3731  Romance  1995

# %%
##### Visualization #####

# %%
merged_df_movies['genre'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
merged_df_movies.plot.scatter(x='year', y='vote_average', colormap='viridis', figsize=(8, 6))
plt.title('Scatter Plot of vote_average by Year')
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/plotting/_matplotlib/core.py:1266: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
filtered_df = merged_df_movies['popularity']
print(filtered_df.mean())
# Out:
# 39.328555995155426

# %%
unique_genres = merged_df_movies['genre'].unique()
unique_genres
# Out:
# array(['Drama', 'Crime', 'Comedy', 'Romance', 'History', 'War', 'Family',
#        'Animation', 'Fantasy', 'Thriller', 'Action', 'Western',
#        'Adventure', 'Horror', 'Science Fiction', 'Music', 'Mystery',
#        'TV Movie'], dtype=object)

# %%
def group_years(genre_name):
    filtered_movies = merged_df_movies[merged_df_movies['genre'] == genre_name].copy()
    high_filtered_df = filtered_movies.loc[:, ['year','popularity']]
    popularity_mean = high_filtered_df.groupby(['year']).mean().reset_index()
    popularity_mean.rename(columns={'popularity':'popularity_' + genre_name.lower()}, inplace=True)

    return popularity_mean

# %%
popularity_mean_matrix = {}

for genre in unique_genres:
    popularity_mean = group_years(genre)
    popularity_mean_matrix[genre]= popularity_mean
    
popularity_mean_matrix
# Out:
# {'Drama':      year  popularity_drama
#  0    1916          7.756000
#  1    1918          6.323000
#  2    1920         15.592000
#  3    1921         12.232000
#  4    1924          5.843000
#  ..    ...               ...
#  96   2018         18.001137
#  97   2019         22.596101
#  98   2020         27.624781
#  99   2021         54.481315
#  100  2022        698.066905
#
#  [101 rows x 2 columns],
#  'Crime':     year  popularity_crime
#  0   1903          7.445000
#  1   1920         15.592000
#  2   1931         10.828000
#  3   1934         10.113000
#  4   1938          5.474000
#  ..   ...               ...
#  80  2018         17.746773
#  81  2019         26.408812
#  82  2020         36.372393
#  83  2021         95.102143
#  84  2022        562.887857
#
#  [85 rows x 2 columns],
#  'Comedy':     year  popularity_comedy
#  0   1917           8.532000
#  1   1918           6.323000
#  2   1921          12.931000
#  3   1923           7.928000
#  4   1924          10.842000
#  ..   ...                ...
#  93  2018          18.884455
#  94  2019          27.850325
#  95  2020          34.493929
#  96  2021         120.980765
#  97  2022         818.027407
#
#  [98 rows x 2 columns],
#  'Romance':     year  popularity_romance
#  0   1923            7.928000
#  1   1927            8.530000
#  2   1928            6.796667
#  3   1930            6.488000
#  4   1931           13.321000
#  ..   ...                 ...
#  89  2018           23.839707
#  90  2019           28.990836
#  91  2020           34.607667
#  92  2021           45.468242
#  93  2022          198.052800
#
#  [94 rows x 2 columns],
#  'History':     year  popularity_history
#  0   1916            7.756000
#  1   1925           12.801000
#  2   1928           10.528000
#  3   1935            8.352000
#  4   1937            7.248000
#  ..   ...                 ...
#  72  2018           19.395848
#  73  2019           18.645314
#  74  2020           11.613067
#  75  2021           56.787188
#  76  2022          114.608400
#
#  [77 rows x 2 columns],
#  'War':     year  popularity_war
#  0   1926       11.124000
#  1   1930       14.554000
#  2   1933        9.082000
#  3   1937        7.248000
#  4   1939       26.427000
#  ..   ...             ...
#  71  2018       18.491000
#  72  2019       24.004154
#  73  2020       27.523625
#  74  2021       93.319800
#  75  2022       44.290000
#
#  [76 rows x 2 columns],
#  'Family':     year  popularity_family
#  0   1928           7.238333
#  1   1933           9.888000
#  2   1937          86.268000
#  3   1939          54.235000
#  4   1940          59.678333
#  ..   ...                ...
#  75  2018          34.061032
#  76  2019          48.226667
#  77  2020          66.729524
#  78  2021         170.959872
#  79  2022        1929.696182
#
#  [80 rows x 2 columns],
#  'Animation':     year  popularity_animation
#  0   1928              7.827000
#  1   1933              9.888000
#  2   1937             86.268000
#  3   1940             85.599500
#  4   1941             70.736000
#  ..   ...                   ...
#  68  2018             47.896097
#  69  2019             53.406591
#  70  2020            107.197300
#  71  2021            211.204298
#  72  2022           1968.846200
#
#  [73 rows x 2 columns],
#  'Fantasy':     year  popularity_fantasy
#  0   1921           11.533000
#  1   1922           16.989000
#  2   1926            7.325000
#  3   1929           10.564000
#  4   1932            7.370000
#  ..   ...                 ...
#  75  2018           34.865019
#  76  2019           58.879196
#  77  2020           77.724960
#  78  2021          207.721585
#  79  2022         2639.354000
#
#  [80 rows x 2 columns],
#  'Thriller':     year  popularity_thriller
#  0   1920            15.592000
#  1   1927            11.135000
#  2   1931             9.937000
#  3   1935            11.120000
#  4   1937            11.312000
#  ..   ...                  ...
#  84  2018            23.178654
#  85  2019            29.457973
#  86  2020            33.494839
#  87  2021           106.561686
#  88  2022           607.856917
#
#  [89 rows x 2 columns],
#  'Action':     year  popularity_action
#  0   1903           7.445000
#  1   1923           7.928000
#  2   1924          10.842000
#  3   1926          11.124000
#  4   1931           9.937000
#  ..   ...                ...
#  72  2018          48.945115
#  73  2019          49.712910
#  74  2020          67.323015
#  75  2021         187.002415
#  76  2022        1975.865556
#
#  [77 rows x 2 columns],
#  'Western':     year  popularity_western
#  0   1903            7.445000
#  1   1939           11.182000
#  2   1942           10.808000
#  3   1946           13.165000
#  4   1948            9.533667
#  ..   ...                 ...
#  57  2018           15.941667
#  58  2019            9.407333
#  59  2020           15.390000
#  60  2021           64.749167
#  61  2022          249.664000
#
#  [62 rows x 2 columns],
#  'Adventure':     year  popularity_adventure
#  0   1902             15.828000
#  1   1925             11.942000
#  2   1926             11.124000
#  3   1933             21.704000
#  4   1935              8.352000
#  ..   ...                   ...
#  79  2018             60.330542
#  80  2019             66.291246
#  81  2020            100.738861
#  82  2021            227.098098
#  83  2022           2572.731105
#
#  [84 rows x 2 columns],
#  'Horror':     year  popularity_horror
#  0   1920          15.592000
#  1   1921          11.533000
#  2   1922          16.989000
#  3   1926           7.325000
#  4   1929          10.564000
#  ..   ...                ...
#  77  2018          30.165414
#  78  2019          38.683157
#  79  2020          43.453983
#  80  2021         117.570592
#  81  2022        1002.443667
#
#  [82 rows x 2 columns],
#  'Science Fiction':     year  popularity_science fiction
#  0   1902                   15.828000
#  1   1927                   15.416000
#  2   1931                   10.832000
#  3   1933                   12.635000
#  4   1935                   12.205000
#  ..   ...                         ...
#  67  2018                   53.059295
#  68  2019                   48.768756
#  69  2020                   50.410406
#  70  2021                  213.491238
#  71  2022                 2132.439889
#
#  [72 rows x 2 columns],
#  'Music':     year  popularity_music
#  0   1928          7.827000
#  1   1933          9.888000
#  2   1935          7.897000
#  3   1944         13.603000
#  4   1946          8.999000
#  ..   ...               ...
#  64  2018         28.800000
#  65  2019         22.051357
#  66  2020         37.059000
#  67  2021        125.421875
#  68  2022        156.492000
#
#  [69 rows x 2 columns],
#  'Mystery':     year  popularity_mystery
#  0   1924           10.842000
#  1   1934           10.113000
#  2   1935           11.120000
#  3   1938            9.814000
#  4   1940           10.502000
#  ..   ...                 ...
#  78  2018           25.107761
#  79  2019           34.604000
#  80  2020           34.313545
#  81  2021          114.722862
#  82  2022          315.971167
#
#  [83 rows x 2 columns],
#  'TV Movie':     year  popularity_tv movie
#  0   1964            18.434000
#  1   1965             9.967000
#  2   1966             7.413000
#  3   1969            10.582000
#  4   1971            20.066000
#  5   1977            18.753000
#  6   1980             7.858000
#  7   1983             7.330500
#  8   1984            10.843500
#  9   1988            27.307500
#  10  1993             7.316000
#  11  1996            10.842000
#  12  1998            10.758000
#  13  1999             7.148000
#  14  2000            13.523000
#  15  2001             9.073000
#  16  2002             9.890000
#  17  2003            10.376000
#  18  2004             9.985000
#  19  2005            22.933000
#  20  2006            16.385714
#  21  2007            21.887800
#  22  2008            13.852250
#  23  2009            17.518429
#  24  2010            16.489286
#  25  2011            14.526667
#  26  2012            17.408714
#  27  2013             9.334600
#  28  2014            13.451800
#  29  2015            25.224727
#  30  2016            16.962000
#  31  2017            18.540000
#  32  2018            43.499000
#  33  2019            33.887200
#  34  2020           118.551600
#  35  2021           133.918667}

# %%
popularity_mean_list = list(popularity_mean_matrix.items())
df_popularity_merged = pd.DataFrame(popularity_mean_list[0][1])

for key, value in popularity_mean_list[1:]:
    df_popularity_merged = pd.merge(df_popularity_merged, value, on='year', how='left')

# %%
df_popularity_merged.head(100)
# Out:
#     year  popularity_drama  popularity_crime  popularity_comedy  \
# 0   1916          7.756000               NaN                NaN
# 1   1918          6.323000               NaN           6.323000
# 2   1920         15.592000         15.592000                NaN
# 3   1921         12.232000               NaN          12.931000
# 4   1924          5.843000               NaN          10.842000
# ..   ...               ...               ...                ...
# 95  2017         20.302982         25.774667          19.983235
# 96  2018         18.001137         17.746773          18.884455
# 97  2019         22.596101         26.408812          27.850325
# 98  2020         27.624781         36.372393          34.493929
# 99  2021         54.481315         95.102143         120.980765
#
#     popularity_romance  popularity_history  popularity_war  popularity_family  \
# 0                  NaN            7.756000             NaN                NaN
# 1                  NaN                 NaN             NaN                NaN
# 2                  NaN                 NaN             NaN                NaN
# 3                  NaN                 NaN             NaN                NaN
# 4                  NaN                 NaN             NaN                NaN
# ..                 ...                 ...             ...                ...
# 95           20.487947           15.980148       19.534526          37.709300
# 96           23.839707           19.395848       18.491000          34.061032
# 97           28.990836           18.645314       24.004154          48.226667
# 98           34.607667           11.613067       27.523625          66.729524
# 99           45.468242           56.787188       93.319800         170.959872
#
#     popularity_animation  popularity_fantasy  popularity_thriller  \
# 0                    NaN                 NaN                  NaN
# 1                    NaN                 NaN                  NaN
# 2                    NaN                 NaN            15.592000
# 3                    NaN           11.533000                  NaN
# 4                    NaN                 NaN                  NaN
# ..                   ...                 ...                  ...
# 95             39.766857           54.842976            23.115492
# 96             47.896097           34.865019            23.178654
# 97             53.406591           58.879196            29.457973
# 98            107.197300           77.724960            33.494839
# 99            211.204298          207.721585           106.561686
#
#     popularity_action  popularity_western  popularity_adventure  \
# 0                 NaN                 NaN                   NaN
# 1                 NaN                 NaN                   NaN
# 2                 NaN                 NaN                   NaN
# 3                 NaN                 NaN                   NaN
# 4           10.842000                 NaN                   NaN
# ..                ...                 ...                   ...
# 95          44.421970           20.227000             59.317155
# 96          48.945115           15.941667             60.330542
# 97          49.712910            9.407333             66.291246
# 98          67.323015           15.390000            100.738861
# 99         187.002415           64.749167            227.098098
#
#     popularity_horror  popularity_science fiction  popularity_music  \
# 0                 NaN                         NaN               NaN
# 1                 NaN                         NaN               NaN
# 2           15.592000                         NaN               NaN
# 3           11.533000                         NaN               NaN
# 4                 NaN                         NaN               NaN
# ..                ...                         ...               ...
# 95          25.787797                   44.705966         38.400000
# 96          30.165414                   53.059295         28.800000
# 97          38.683157                   48.768756         22.051357
# 98          43.453983                   50.410406         37.059000
# 99         117.570592                  213.491238        125.421875
#
#     popularity_mystery  popularity_tv movie
# 0                  NaN                  NaN
# 1                  NaN                  NaN
# 2                  NaN                  NaN
# 3                  NaN                  NaN
# 4            10.842000                  NaN
# ..                 ...                  ...
# 95           25.546388            18.540000
# 96           25.107761            43.499000
# 97           34.604000            33.887200
# 98           34.313545           118.551600
# 99          114.722862           133.918667
#
# [100 rows x 19 columns]

# %%
# group 1: drama, horror, fantasy and history
fig, ax = plt.subplots(figsize=(16, 8))
plt.title('Average popularity of films by genre (Group 1)')
plt.ylabel('Average Annual Popularity')
plt.xlabel('Release Year')
plt.xticks(np.arange(1960, 2016, 2))
ax.plot('year', 'popularity_drama', data=df_popularity_merged, label="Drama")
ax.plot('year', 'popularity_horror', data=df_popularity_merged, label="Horror")
ax.plot('year', 'popularity_fantasy', data=df_popularity_merged, label="Fantasy")
ax.plot('year', 'popularity_history', data=df_popularity_merged, label="History")
ax.legend(loc='upper left');
