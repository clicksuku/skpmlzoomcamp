# %%
import pandas as pd
import json
import numpy as np
import seaborn as sn
from matplotlib import pyplot as plt
from io import StringIO
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.metrics import auc, roc_auc_score, roc_curve, classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction import DictVectorizer

# %%
###Data Cleanup and EDA####

# %%
df_movies =  pd.read_csv('5kMovies.csv')
df_credits = pd.read_csv('5kCredits.csv')

# %%
df_tmdb = pd.concat([df_movies, df_credits], axis=1)

# %%
new_column_order = ['id', 'title', 'original_language', 'cast','genres', 'release_date','runtime', 'popularity', 'vote_count', 'vote_average', 'budget', 'revenue']

# %%
genres_list = ['Action', 'Adventure', 'Fantasy', 'Science Fiction', 'Thriller', 'Comedy']

# %%
def data_cleanup(df, new_columns):
    df_tmdb_new = df[new_column_order]
    df_tmdb_new = df_tmdb_new.loc[:, ~df_tmdb_new.columns.duplicated()]
    
    categorical= list(df_tmdb_new.dtypes[df_tmdb_new.dtypes=='object'].index)
    numerical = list(df_tmdb_new.dtypes[df_tmdb_new.dtypes!='object'].index)
    
    for c in categorical:
        df_tmdb_new.loc[:,c] = df_tmdb_new.loc[:,c].fillna('NA')

    for c in numerical:
        df_tmdb_new.loc[:,c] = df_tmdb_new.loc[:,c].fillna(0)

    
    df_tmdb_new.columns = ['id', 'title', 'language', 'cast','genres', 'release_date','runtime', 'popularity', 'vote_count', 'vote_avg', 'budget', 'revenue']
    
    df_filtered = df_tmdb_new[df_tmdb_new['genres'].str.len() > 2]
    return df_filtered

# %%
def jsontocsv(jsonstr:list):
    if len(jsonstr) < 3:
        return 'NA'
    df = pd.read_json(StringIO(jsonstr))
    csv_string = ', '.join(df['name'].apply(str))
    return csv_string

# %%
def genres_json_to_csv(row):
    return jsontocsv(row['genres'])

# %%
def normalize_genres(df_movies):
    df_movies['genres_csv'] = df_movies.apply(genres_json_to_csv, axis=1)
    for g in genres_list:
        df_movies[g] = df_movies['genres_csv'].apply(lambda x: g in x)
    df_movies = df_movies.drop('genres_csv', axis=1)
    df_movies = df_movies.drop('genres', axis=1)
    df_movies.columns = ['id', 'title', 'language', 'cast','Action', 'Adventure', 'Fantasy', 'Science Fiction', 'Thriller', 'Comedy', 'release_date','runtime', 'popularity', 'vote_count', 'vote_avg', 'budget', 'revenue']
    return df_movies

# %%
df_movies = data_cleanup(df_tmdb, new_column_order)
df_movies = normalize_genres(df_movies)

# %%
df_movies.head(10)
# Out:
#        id                                     title language  \
# 0   19995                                    Avatar       en
# 1     285  Pirates of the Caribbean: At World's End       en
# 2  206647                                   Spectre       en
# 3   49026                     The Dark Knight Rises       en
# 4   49529                               John Carter       en
# 5     559                              Spider-Man 3       en
# 6   38757                                   Tangled       en
# 7   99861                   Avengers: Age of Ultron       en
# 8     767    Harry Potter and the Half-Blood Prince       en
# 9  209112        Batman v Superman: Dawn of Justice       en
#
#                                                 cast      Action  Adventure  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...  2009-12-10      162.0
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...  2007-05-19      169.0
# 2  [{"cast_id": 1, "character": "James Bond", "cr...  2015-10-26      148.0
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...  2012-07-16      165.0
# 4  [{"cast_id": 5, "character": "John Carter", "c...  2012-03-07      132.0
# 5  [{"cast_id": 30, "character": "Peter Parker / ...  2007-05-01      139.0
# 6  [{"cast_id": 34, "character": "Flynn Rider (vo...  2010-11-24      100.0
# 7  [{"cast_id": 76, "character": "Tony Stark / Ir...  2015-04-22      141.0
# 8  [{"cast_id": 3, "character": "Harry Potter", "...  2009-07-07      153.0
# 9  [{"cast_id": 18, "character": "Bruce Wayne / B...  2016-03-23      151.0
#
#       Fantasy  Science Fiction  Thriller     Comedy  release_date  runtime  \
# 0  150.437577            11800       7.2  237000000    2787965087     True
# 1  139.082615             4500       6.9  300000000     961000000     True
# 2  107.376788             4466       6.3  245000000     880674609     True
# 3  112.312950             9106       7.6  250000000    1084939099     True
# 4   43.926995             2124       6.1  260000000     284139100     True
# 5  115.699814             3576       5.9  258000000     890871626     True
# 6   48.681969             3330       7.4  260000000     591794936    False
# 7  134.279229             6767       7.3  280000000    1405403694     True
# 8   98.885637             5293       7.4  250000000     933959197    False
# 9  155.790452             7004       5.7  250000000     873260194     True
#
#    popularity  vote_count  vote_avg  budget  revenue
# 0        True        True      True   False    False
# 1        True        True     False   False    False
# 2        True       False     False   False    False
# 3       False       False     False    True    False
# 4        True       False      True   False    False
# 5        True        True     False   False    False
# 6       False       False     False   False    False
# 7        True       False      True   False    False
# 8        True        True     False   False    False
# 9        True        True     False   False    False
